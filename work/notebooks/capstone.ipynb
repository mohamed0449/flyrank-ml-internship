# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohamed0449/flyrank-ml-internship/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# # Prioritizing SEO Content Refreshes: A Predictive Ranking Model for Action Queues
#
# **Abstract**
# Content teams often struggle to prioritize which aging articles to refresh under strict review budgets. This project develops a machine learning ranking model to identify high-potential declining content. Using a robust client-grouped validation split to prevent data leakage, a Random Forest Regressor was trained on historical SEO metadata (e.g., impressions, average position). The model successfully outperformed a naive baseline, effectively ranking pages that require immediate attention. This playbook serves as a directional, decision-support tool rather than an automated publishing system.
#
# **Introduction / Problem Statement**
# Organic search traffic decays over time. When a team can only manually review a limited number of pages (e.g., 50 pages a month), the order of the review queue is critical. A model that nobody acts on is just a science project; therefore, the goal of this research is to build a ranked action queue that maximizes the impact of human editorial time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Data
#
#
# The model was built using an anonymized subset of real production search data (79 million rows originally).
# *   **Included Features:** Safe, historical metrics such as `search_volume`, `competition`, `avg_position`, and `content_age_days`.
# *   **Exclusions for Public Safety & Leakage:** Client names, URLs, and private queries were strictly excluded. Furthermore, downstream metrics like `sessions_90d` and `pageviews_90d` were dropped from the feature set to prevent target leakage, as they occur alongside or after the target variable (`clicks_90d`).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Methodology
#
# *   **Algorithm:** Random Forest Regressor was chosen for its robustness against non-linear relationships.
# *   **Validation Design:** A naive random split yielded artificially optimistic results due to client-data memorization. To ensure an honest evaluation, a `GroupShuffleSplit` on `client_id` was strictly enforced. This guarantees the model is evaluated on its ability to generalize to unseen clients.
# *   **Baseline:** The model was evaluated against a simple Mean Predictor (Dummy Regressor) on the exact same grouped split.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Results (Model vs baseline)
#
# Under the strict client-grouped split, the Random Forest model achieved a lower Mean Absolute Error (MAE) compared to the naive mean baseline. While a random split previously showed a near-perfect (but misleading) score, the grouped split provided a realistic, measured expectation of performance on new data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Limitations
#
#
# *   **Predictive, Not Causal:** This model observes correlations between metrics (like position and clicks) but does not prove that updating a specific feature will *cause* a traffic recovery.
# *   **Time-Window Limits:** The evaluation was conducted on a single time-window snapshot. Continuous monitoring and retraining are required to account for major Google Algorithm updates.
# *   **No Content Context:** The model reads metadata, not the actual written text. It cannot judge brand safety or tone.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 6. **Ranked Recommendations (Action Playbook)**
# The model's output is transformed into a human-in-the-loop playbook with the following ranked reason codes:
# 1.  **REFRESH_HIGH_POTENTIAL:** High search volume, poor position, content older than 365 days. Action: Send to editor for rewrite.
# 2.  **MONITOR_DECAY:** Content aging past 180 days with slight dips. Action: Hold and observe next month's queue.
#
# *Guardrails:* Automated publishing is strictly prohibited. URLs cannot be redirected without human SEO expert approval.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 7. **Reproducibility**
# All code, methodology, and exported figures are available in the repository. The environment, random seeds (`random_state=42`), and validation splits are fully documented to allow exact replication of the metrics.
#
# **Acknowledgments & Data Credit**
# Repository Link: https://github.com/mohamed0449/flyrank-ml-internship
# Built on the FlyRank ML Internship dataset. Special thanks to the FlyRank team for the mentorship and resources.
# Dataset and program details: https://flyrank.ai

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [O] Every section above is filled — markdown thinking AND the code that backs it
# - [O] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [O] No client names, URLs, or private queries anywhere
# - [O] My claims use careful words: observed, measured, directional, decision-support
# - [O] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# # Tell the Story: Case Study, Demo Outline, and Shareable Cuts
#
# ## 1. Case Study Framing (FlyRank Context)
# *Note: This is already reflected in the main Abstract/Introduction, but stated here for clarity.*
# **Problem:** At FlyRank, content teams need to optimize aging articles, but human review bandwidth is strictly limited.
# **Solution:** I developed a machine learning ranking model that prioritizes declining content based on SEO metadata. Instead of replacing human editors, this model acts as a decision-support playbook, generating a ranked action queue that maximizes the impact of the editorial team's limited time.
#
# ## 2. 5-Minute Demo Outline (Showcase Ready)
# **1. The Question (1 min):** How do we prioritize which aging articles to refresh when an editor can only review 50 pages a month?
# **2. The Method (1 min):** I built a Random Forest Regressor using historical SEO data (impressions, age, position). Crucially, I used a `GroupShuffleSplit` (grouped by client_id) to prevent data leakage and ensure the model generalizes to new clients.
# **3. One Chart / Visual (1 min):** *(Show the Precision@K or Model vs. Baseline Error Chart)*. Highlighting how the model outperforms a naive baseline specifically at the top of the queue (the 50-page budget).
# **4. One Honest Result (1 min):** The model successfully identifies high-potential content, but it is *predictive, not causal*. It flags the drops but doesn't guarantee a traffic recovery just by updating the page.
# **5. One Recommendation (1 min):** Implement the "Content Action Playbook"—a prioritized queue where the model ranks the urgency, and humans review for context before executing any updates. Never automate publishing.
#
# ## 3. Two Shareable Cuts
#
# ### Cut A: Social Media Post (Focus on Methodology)
# "Just wrapped up my ML Capstone! 🚀 I built a predictive ranking model to prioritize SEO content refreshes. The biggest lesson? Validation design matters. A naive random split gave me an artificially perfect score, but using a client-grouped split (`GroupShuffleSplit`) prevented data leakage and gave an *honest*, real-world metric. Always check what your model is actually memorizing! #MachineLearning #DataScience #SEO"
#
# ### Cut B: Employer-Facing Summary (3-Sentence Focus)
# **What I built, on what data, what it showed:**
# I built a decision-support ranking model to prioritize SEO content refreshes for editorial teams with limited bandwidth. Using an anonymized dataset of historical production search data, I engineered features while strictly excluding target-leaking downstream metrics. The validated model successfully outperformed naive baselines under a rigorous grouped-split, proving its utility as a reliable action playbook to maximize editorial impact.
